# %%
import numpy as np
import pandas as pd

# %%
#loading the data from csv file to pandas dataframe
air_quality_data = pd.read_csv('/content/AirQualityUCI.csv', sep = ';', decimal = ',')

# %%
air_quality_data.loc[[9356]]
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 9356        816.0  28.5  13.1  0.5028          NaN          NaN

# %%
air_quality_data = air_quality_data.head(9357)

# %%
air_quality_data.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN
# 3  11.0  60.0  0.7867          NaN          NaN
# 4  11.2  59.6  0.7888          NaN          NaN

# %%
air_quality_data.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 9352       1729.0  21.9  29.3  0.7568          NaN          NaN
# 9353       1269.0  24.3  23.7  0.7119          NaN          NaN
# 9354       1092.0  26.9  18.3  0.6406          NaN          NaN
# 9355        770.0  28.3  13.5  0.5139          NaN          NaN
# 9356        816.0  28.5  13.1  0.5028          NaN          NaN

# %%
air_quality_data.shape
# Out:
# (9357, 17)

# %%
#removing the last 2 columns from the dataframe
air_quality_data = air_quality_data.iloc[:, :-2]

# %%
#getting some info about the data
air_quality_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
#counting the number of times-200 appears in the data
air_quality_data.isin([-200]).sum(axis=0)
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
air_quality_data = air_quality_data.fillna(air_quality_data.mean())
# Out:
# <ipython-input-66-92e882c4d405>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   air_quality_data = air_quality_data.fillna(air_quality_data.mean())

# %%
air_quality_data = air_quality_data.replace(to_replace=-200, value = np.NaN)

# %%
air_quality_data.isnull().sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
air_quality_data.mean()
# Out:
# <ipython-input-62-d7366ba731bb>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   air_quality_data.mean()
# CO(GT)              2.152750
# PT08.S1(CO)      1099.833166
# NMHC(GT)          218.811816
# C6H6(GT)           10.083105
# PT08.S2(NMHC)     939.153376
# NOx(GT)           246.896735
# PT08.S3(NOx)      835.493605
# NO2(GT)           113.091251
# PT08.S4(NO2)     1456.264598
# PT08.S5(O3)      1022.906128
# T                  18.317829
# RH                 49.234201
# AH                  1.025530
# dtype: float64

# %%
#replacing the mising values with mean value
air_quality_data = air_quality_data.fillna(air_quality_data.mean())
# Out:
# <ipython-input-63-2a7351d98719>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   air_quality_data = air_quality_data.fillna(air_quality_data.mean())

# %%
date_info = pd.to_datetime(air_quality_data['Date'])
print(date_info)
# Out:
# 0      2004-10-03
# 1      2004-10-03
# 2      2004-10-03
# 3      2004-10-03
# 4      2004-10-03
#           ...
# 9352   2005-04-04
# 9353   2005-04-04
# 9354   2005-04-04
# 9355   2005-04-04
# 9356   2005-04-04
# Name: Date, Length: 9357, dtype: datetime64[ns]
# <ipython-input-68-3763380cde41>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   date_info = pd.to_datetime(air_quality_data['Date'])

# %%
time_info = air_quality_data['Time']

# %%
time_info = time_info.apply(lambda x:x.replace('.',':'))

# %%
print(type(date_info))
print(type(time_info))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
print(time_info)
# Out:
# 0       18:00:00
# 1       19:00:00
# 2       20:00:00
# 3       21:00:00
# 4       22:00:00
#           ...
# 9352    10:00:00
# 9353    11:00:00
# 9354    12:00:00
# 9355    13:00:00
# 9356    14:00:00
# Name: Time, Length: 9357, dtype: object

# %%
#combining 2 series to a pandas dataframe
date_time = pd.concat([date_info, time_info], axis=1)

# %%
date_time.head()
# Out:
#         Date      Time
# 0 2004-10-03  18:00:00
# 1 2004-10-03  19:00:00
# 2 2004-10-03  20:00:00
# 3 2004-10-03  21:00:00
# 4 2004-10-03  22:00:00

# %%
date_time.shape
# Out:
# (9357, 2)

# %%
date_time['ds']= date_time['Date'].astype(str)+' '+ date_time['Time'].astype(str)

# %%
date_time.head()
# Out:
#         Date      Time                   ds
# 0 2004-10-03  18:00:00  2004-10-03 18:00:00
# 1 2004-10-03  19:00:00  2004-10-03 19:00:00
# 2 2004-10-03  20:00:00  2004-10-03 20:00:00
# 3 2004-10-03  21:00:00  2004-10-03 21:00:00
# 4 2004-10-03  22:00:00  2004-10-03 22:00:00

# %%
date_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9357 non-null   datetime64[ns]
#  1   Time    9357 non-null   object
#  2   ds      9357 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 219.4+ KB

# %%
data =pd.DataFrame()

# %%
data['ds']= pd.to_datetime(date_time['ds'])

# %%
data.head()
# Out:
#                    ds
# 0 2004-10-03 18:00:00
# 1 2004-10-03 19:00:00
# 2 2004-10-03 20:00:00
# 3 2004-10-03 21:00:00
# 4 2004-10-03 22:00:00

# %%
data['y'] =air_quality_data['RH']

# %%
data.head()
# Out:
#                    ds     y
# 0 2004-10-03 18:00:00  48.9
# 1 2004-10-03 19:00:00  47.7
# 2 2004-10-03 20:00:00  54.0
# 3 2004-10-03 21:00:00  60.0
# 4 2004-10-03 22:00:00  59.6

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.41)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.1.1)
# Requirement already satisfied: stanio~=0.3.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
from prophet import Prophet

# %% [markdown]
# training the prophet model

# %%
model = Prophet()
model.fit(data)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkn_z7xrd/7afseo1k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkn_z7xrd/vl8js40q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95999', 'data', 'file=/tmp/tmpkn_z7xrd/7afseo1k.json', 'init=/tmp/tmpkn_z7xrd/vl8js40q.json', 'output', 'file=/tmp/tmpkn_z7xrd/prophet_modelmvkbmvkd/prophet_model-20240127111235.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:12:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:12:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=365, freq='H')
future.tail()
# Out:
#                       ds
# 9717 2005-12-19 00:00:00
# 9718 2005-12-19 01:00:00
# 9719 2005-12-19 02:00:00
# 9720 2005-12-19 03:00:00
# 9721 2005-12-19 04:00:00

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
#                    ds       yhat  yhat_lower  yhat_upper
# 0 2004-01-04 00:00:00  61.397786   44.542564   78.021631
# 1 2004-01-04 01:00:00  62.963117   46.379860   79.426081
# 2 2004-01-04 02:00:00  64.229403   46.907302   80.944699
# 3 2004-01-04 03:00:00  65.204927   48.161622   81.756393
# 4 2004-01-04 04:00:00  66.173905   48.086053   84.201560
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['yhat'].plot(kind='hist', bins=20, title='yhat')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13